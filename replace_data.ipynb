# %%
import numpy as np
import pandas as pd

# %%
data_set=pd.read_csv(r'C:\Users\DELL\Downloads\billionaires.csv')

# %%
data_set.fillna(value=100)
#to put all the null values as that value we pass
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
data_set['year'].fillna(value=2015)
#in that column which value is null it will be replaced with the parameter we pass
# Out:
# 0       1996
# 1       2001
# 2       2014
# 3       1996
# 4       2001
#         ...
# 2609    2014
# 2610    2014
# 2611    2014
# 2612    2014
# 2613    2014
# Name: year, Length: 2614, dtype: int64

# %%
m=data_set['year'].mean()

# %%
m
# Out:
# 2008.4116296863044

# %%
r=data_set['year'].mode()

# %%
r
# Out:
# 0    2014
# Name: year, dtype: int64

# %%
s=data_set['year'].median()

# %%
s
# Out:
# 2014.0

# %%
v=data_set['year'].var()
#for getting variance

# %%
v
# Out:
# 56.00424280809292

# %%
e=data_set['year'].std()
#for getting standard deviation

# %%
e
# Out:
# 7.483598252718602

# %%
data_set.drop(8)
#to drop pariticular row
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...

# %%
#to drop multiple rows list need to passed
data_set.drop([4,5,6])
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 7         Paul Allen     3  2001             1975
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 7                           Microsoft              founder
# ...

# %%
data_set.drop(['name','company.name'],axis=1)
#to drop columnssss
# Out:
#       rank  year  company.founded company.relationship      company.sector  \
# 0        1  1996             1975              founder            Software
# 1        1  2001             1975              founder            Software
# 2        1  2014             1975              founder            Software
# 3        2  1996             1962              founder             Finance
# 4        2  2001             1962              founder             Finance
# ...    ...   ...              ...                  ...                 ...
# 2609  1565  2014             1991             investor  beverages and food
# 2610  1565  2014             1999                owner      infant formula
# 2611  1565  2014                0             chairman         real estate
# 2612  1565  2014             1994              founder                coal
# 2613  1565  2014             1999             chairman     pharmaceuticals
#
# ...

# %%
data_set['year'].fillna(value=2050)
# Out:
# 0       1996
# 1       2001
# 2       2014
# 3       1996
# 4       2001
#         ...
# 2609    2014
# 2610    2014
# 2611    2014
# 2612    2014
# 2613    2014
# Name: year, Length: 2614, dtype: int64
